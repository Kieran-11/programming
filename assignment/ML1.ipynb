# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,1,50)
y = np.log(x)
z = np.exp(x)
plt.scatter(x,y,label = 'Log')
plt.scatter(x,z,label = 'Exponential')
plt.xlabel('X vals')
plt.ylabel('Y/Z vals')
plt.title('Logarithmic and Exponential Graphs')
plt.legend(loc = 'lower right')
plt.show()
# Out:
# <ipython-input-14-3e5c82bf0bb9>:2: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)

# %%
x= np.linspace(-6.5, 6.5, 100)
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y, label = 'sin')
plt.plot(x,z, label = 'cos')
plt.xlabel('X vals')
plt.ylabel('Y vals')
plt.legend(loc = 'lower left')
plt.show()
